# %%
import pandas as pd
from src.scrapping_house import HouseScrapping
from src.scrapping_ids import IdsScrapping

# pip install --upgrade undetected_chromedriver

# %%
base_url = "https://www.idealista.com/venta-viviendas/toledo/buenavista-valparaiso-la-legua/"
obtainer = IdsScrapping(base_url)
house_ids = obtainer.obtain_ids()
print(house_ids[:5])
print(len(house_ids))
# Out:
# [104391325, 104773412, 103685341, 102747147, 104837756]
# 57

# %%
house_dfs = []

for i, house_id in enumerate(house_ids):
    if i % 10 == 0:
        print(i)
    url = f"https://www.idealista.com/inmueble/{house_id}/"
    scrapper = HouseScrapping(url)
    house_info = scrapper.get_house_information()
    house_info["id"] = house_id
    house_dfs.append(house_info)
# Out:
# 0
# 10
# 20
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[3], line 7
#       5     print(i)
#       6 url = f"https://www.idealista.com/inmueble/{house_id}/"
# ----> 7 scrapper = HouseScrapping(url)
#       8 house_info = scrapper.get_house_information()
#       9 house_info["id"] = house_id
#
# File c:\Users\anton\OneDrive\Escritorio\scrapping\src\scrapping_house.py:28, in HouseScrapping.__init__(self, url)
#      19 """
#      20 Constructor of the class.
#      21
#    (...)
#      24 url : Url of the advertisement
#      25 """
#      27 self.url = url
# ---> 28 browser = uc.Chrome()
#      29 browser.get(url)
#      30 wait()
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\undetected_chromedriver\__init__.py:466, in Chrome.__init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, desired_capabilities, advanced_elements, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, user_multi_procs, **kw)
#     459     self.browser_pid = browser.pid
#     462 service = selenium.webdriver.chromium.service.ChromiumService(
#     463     self.patcher.executable_path
#     464 )
# --> 466 super(Chrome, self).__init__(
#     467     service=service,
#     468     options=options,
#     469     keep_alive=keep_alive,
#     470 )
#     472 self.reactor = None
#     474 if enable_cdp_events:
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:61, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#      60 try:
# ---> 61     super().__init__(command_executor=executor, options=options)
#      62 except Exception:
#      63     self.quit()
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\undetected_chromedriver\__init__.py:724, in Chrome.start_session(self, capabilities, browser_profile)
#     722 if not capabilities:
#     723     capabilities = self.options.to_capabilities()
# --> 724 super(selenium.webdriver.chrome.webdriver.WebDriver, self).start_session(
#     725     capabilities
#     726 )
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: cannot connect to chrome at 127.0.0.1:54413
# from chrome not reachable
# Stacktrace:
# 	GetHandleVerifier [0x005CC1C3+27395]
# 	(No symbol) [0x00563DC4]
# 	(No symbol) [0x004619FD]
# 	(No symbol) [0x004503AC]
# 	(No symbol) [0x00493D22]
# 	(No symbol) [0x0048AD50]
# 	(No symbol) [0x0048AB97]
# 	(No symbol) [0x004CD58E]
# 	(No symbol) [0x004CCDAA]
# 	(No symbol) [0x004C3736]
# 	(No symbol) [0x00497541]
# 	(No symbol) [0x004980BD]
# 	GetHandleVerifier [0x00883A93+2876371]
# 	GetHandleVerifier [0x008D7F5D+3221661]
# 	GetHandleVerifier [0x0064D634+556916]
# 	GetHandleVerifier [0x0065474C+585868]
# 	(No symbol) [0x0056CE04]
# 	(No symbol) [0x00569818]
# 	(No symbol) [0x005699B7]
# 	(No symbol) [0x0055BF0E]
# 	BaseThreadInitThunk [0x772A7BA9+25]
# 	RtlInitializeExceptionChain [0x7797C10B+107]
# 	RtlClearBits [0x7797C08F+191]

# %%
df = pd.DataFrame(house_dfs)
cols = ["id"] + [col for col in df.columns if col != "id"]
df = df[cols]
df.head()
# Out:
#                                                title  \
# 0            Piso en venta en calle de los Concilios
# 1                  Piso en venta en ronda Buenavista
# 2    Piso en venta en Buenavista-Valparaíso-La Legua
# 3    Chalet adosado en venta en avenida del Olmo, 58
# 4   Chalet adosado en venta en Buenavista-Valpara...
#
#                          location   price   m2   type  \
# 0  Buenavista-Valparaíso-La Legua  274900  115   flat
# 1  Buenavista-Valparaíso-La Legua  254990   93   flat
# 2                          Toledo  227000   90   flat
# 3  Buenavista-Valparaíso-La Legua  272000  150  house
# 4                          Toledo  349000  224  house
#
#                      status               floor  \
# 0  Segunda mano/buen estado  Planta 1ª exterior
# 1  Segunda mano/buen estado  Planta 3ª exterior
# 2  Segunda mano/buen estado  Planta 1ª exterior
# 3  Segunda mano/buen estado                None
# 4  Segunda mano/buen estado           3 plantas
#
#                                          description  n_photos  n_rooms  ...  \
# 0  Agencia inmobiliaria en Toledo zona Avenida Eu...         0        3  ...
# 1  Agencia Inmobiliaria de Toledo zona Santa Tere...         0        4  ...
# 2  Piso en venta en Buenavista, es una acogedora ...         0        4  ...
# 3  EN VENTA_chalet_VALPARAISO. En avenida princip...         0        4  ...
# 4  CHALET ADOSADO en la zona de Valparaíso (Toled...         0        5  ...
#
#    virtual_tour  3d_tour  plane  air_conditioning  \
# 0         False    False   True              True
# 1          True    False   True             False
# 2          True    False   True              True
# 3          True    False   True             False
# 4          True    False   True              True
#
#                                heating  elevator  furnished           terrace  \
# 0  Calefacción individual: Gas natural      True       None              None
# 1  Calefacción individual: Gas natural      True       None           Terraza
# 2               Calefacción individual      True       None           Terraza
# 3  Calefacción individual: Gas natural      None       None  Terraza y balcón
# 4  Calefacción individual: Gas natural      None       None           Terraza
#
#   consume emisions
# 0       C        C
# 1       C        C
# 2       C        C
# 3       C     None
# 4       C        C
#
# [5 rows x 24 columns]
