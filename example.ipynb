# %%
import pandas as pd

from src.main import main

# %%
base_url = (
    "https://www.idealista.com/venta-viviendas/toledo/buenavista-valparaiso-la-legua/"
)

houses_df = main(base_url)
# Out:
# Empezamos
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 5
#       1 base_url = (
#       2     "https://www.idealista.com/venta-viviendas/toledo/buenavista-valparaiso-la-legua/"
#       3 )
# ----> 5 houses_df = main(base_url)
#
# File c:\Users\anton\OneDrive\Escritorio\scrapping\src\main.py:70, in main(base_url, save_every)
#      60 """
#      61 Scraping of all houses of a given zone.
#      62
#    (...)
#      66 print_every : To save the progress of the scraping of the house ids
#      67 """
#      69 # obtain house ids
# ---> 70 obtainer = IdsScraping(base_url)
#      71 house_ids = obtainer.obtain_ids()
#      72 house_ids_df = pd.DataFrame({"house_id": house_ids})
#
# File c:\Users\anton\OneDrive\Escritorio\scrapping\src\scraping_ids.py:25, in IdsScraping.__init__(self, base_url)
#      23 print("Empezamos")
#      24 self.base_url = base_url
# ...

# %%
df = pd.read_csv("data/houses_df.csv")
df.head()
# Out:
#           id                                              title  \
# 0  104391325            Piso en venta en calle de los Concilios
# 1  104758850   Chalet adosado en venta en Buenavista-Valpara...
# 2  104773412                  Piso en venta en ronda Buenavista
# 3  102747147   Chalet adosado en venta en Buenavista-Valpara...
# 4  103685341    Chalet adosado en venta en avenida del Olmo, 58
#
#                          location   price   m2   type  \
# 0  Buenavista-Valparaíso-La Legua  274900  115   flat
# 1                          Toledo  399900  150  house
# 2  Buenavista-Valparaíso-La Legua  254990   93   flat
# 3                          Toledo  289000  163  house
# 4  Buenavista-Valparaíso-La Legua  272000  150  house
#
#                      status               floor  \
# 0  Segunda mano/buen estado  Planta 1ª exterior
# 1  Segunda mano/buen estado           2 plantas
# 2  Segunda mano/buen estado  Planta 3ª exterior
# 3  Segunda mano/buen estado           3 plantas
# ...
